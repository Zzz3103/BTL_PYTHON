# %%
from facebook_scraper import get_posts
import pandas as pd
import numpy as np

# %%
FANPAGE_LINK ="adidasVN"
FOLDER_PATH = "../Data/"
COOKIE_PATH = "../Data/www.facebook.com_cookies.txt"

PAGES_NUMBER = 30

# %%
post_list = []
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "allow_extra_requests": True},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH):
    print(post)
    post_list.append(post)
# Out:
# {'post_id': '657411463205036', 'text': '🏀🏀 MÊ TAN, LÀ CH4\nMÊ…MẨN TỪ ÁNH NHÌN ĐẦU TIÊN, LÀ ADIDAS RIVALRY\n\nKhông cần chất xúc tác adidas Rivalry vẫn có thể tạo nên phản ứng nhờ phối màu nổi bật. Cùng với chi tiết phủ ngoài bằng nubuck thời thượng, bạnXem thêm chính là tâm điểm mỗi nơi đặt chân tới.\n\n👉 Sở hữu ngay tại: https://a.did.as/6187uYVkB\nHoặc tại các cửa hàng adidas nhé!\n\n#adidasVN #adidasOriginals', 'post_text': '🏀🏀 MÊ TAN, LÀ CH4\nMÊ…MẨN TỪ ÁNH NHÌN ĐẦU TIÊN, LÀ ADIDAS RIVALRY\n\nKhông cần chất xúc tác adidas Rivalry vẫn có thể tạo nên phản ứng nhờ phối màu nổi bật. Cùng với chi tiết phủ ngoài bằng nubuck thời thượng, bạnXem thêm chính là tâm điểm mỗi nơi đặt chân tới.\n\n👉 Sở hữu ngay tại: https://a.did.as/6187uYVkB\nHoặc tại các cửa hàng adidas nhé!\n\n#adidasVN #adidasOriginals', 'shared_text': '', 'original_text': None, 'time': datetime.datetime(2023, 11, 20, 19, 14, 13), 'timestamp': 1700482453, 'image': None, 'image_lowquality': 'https://scontent.fhan19-1.fna.fb
# ...

# %%
# Initialize dataframe to scrape Facebook post

post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# lưu file csv, xlsx, npy
path1=FOLDER_PATH + 'adidasVN' + ".csv"
path2=FOLDER_PATH + 'adidasVN' + ".xlsx"
post_df_full.to_csv(path1, index=False)
post_df_full.to_excel(path2,index=False)
arr = np.array(post_list)
np.save('../Data/adidas_py.npy',arr)
